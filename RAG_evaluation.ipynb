# %%
import os
import openai
from getpass import getpass

openai.api_key = getpass("Please provide your OpenAI Key: ")
os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader(
    "data/2025-DOST-SEI-ST-Scholars-Handbook-Final.pdf",
)

all_documents = loader.load()

# %%
# Use all documents without limiting
print('Total pages', len(all_documents))
documents = all_documents
print('# of pages - All documents', len(documents))
print('First page', documents[0].page_content)
# Out:
# Total pages 52
# # of pages - All documents 52
# First page

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 600,
    chunk_overlap = 150,
    separators=["\n\n", "\n", ". ", " ", ""]
)

chunks = text_splitter.split_documents(documents)

# %% [markdown]
# Let's confirm we've split our document.

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-ada-002"
)

# %% [markdown]
# #### Creating a QDrant VectorStore
#
# Now that we have documents - we'll need a place to store them alongside their embeddings.

# %%
from langchain_community.vectorstores import Qdrant

qdrant_vector_store = Qdrant.from_documents(
    chunks,
    embeddings,
    location=":memory:",
    collection_name="DOST_Handbook",
)

# %%
# --- Base Retriever ---
retriever = qdrant_vector_store.as_retriever(search_kwargs={"k": 7})

from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

compressor = LLMChainExtractor.from_llm(primary_qa_llm)
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=retriever,
)

# Now wrap MultiQueryRetriever with compression
advanced_retriever = MultiQueryRetriever.from_llm(
    retriever=compression_retriever,
    llm=primary_qa_llm,
)

# %%
# --- Custom Prompt (encourages detailed answers) ---
from langchain.prompts import ChatPromptTemplate

template = """
You are an assistant for DOST-SEI scholars answering questions using the official handbook.

CRITICAL INSTRUCTIONS:
1. Answer ONLY based on the provided context below
2. Do NOT add information not present in the context
3. If you're unsure, say "I need more specific information from the handbook" or "Can you give mo more context to your question?"
4. Quote specific sections when possible
Context:
{context}

Question:
{input}
"""
prompt = ChatPromptTemplate.from_template(template)

# %%
# --- Document Chain ---
from langchain.chains.combine_documents import create_stuff_documents_chain

document_chain = create_stuff_documents_chain(primary_qa_llm, prompt)

# %%
# --- Retrieval Chain ---
from langchain.chains import create_retrieval_chain

retrieval_chain = create_retrieval_chain(advanced_retriever, document_chain)

# %%
# --- Guardrails Placeholder ---
def guardrails_pre_query(user_input: str) -> str:
    """Check if input is safe and relevant before querying retriever."""
    blocked = ["violence", "politics", "religion"]  # Example guardrails
    if any(b in user_input.lower() for b in blocked):
        return "Sorry, I cannot answer that type of question."
    return user_input

def guardrails_post_response(response: str) -> str:
    """Check if response is hallucinated or irrelevant before sending to user."""
    if "I don't know" in response or len(response.strip()) < 20:
        response += "\n\n⚠️ This answer may be incomplete. Please verify in the official handbook."
    return response

# %%
# --- Single Question ---
question = "I have a failed grade in my semester, am I terminated already? This is my first failed grade, I am still in my second year in college"

# Apply pre-query guardrail
safe_query = guardrails_pre_query(question)
if safe_query.startswith("Sorry"):
    print(safe_query)
else:
    # Invoke the retrieval-augmented chain
    result = retrieval_chain.invoke({"input": safe_query})
    
    # Apply post-response guardrail
    safe_response = guardrails_post_response(result["answer"])
    
    # Print formatted output
    print(f"\nQ: {question}\nA: {safe_response}\n{'-'*50}")
# Out:
# Q: I have a failed grade in my semester, am I terminated already? This is my first failed grade, I am still in my second year in college
# A: Based on the context provided, if you have one grade of 5.0/F without any previous deficiency, you would be "Continued under Probation." Therefore, you are not terminated yet. However, if you have any previous deficiencies, the situation may differ. Since you mentioned this is your first failed grade, you should be under probation.
# --------------------------------------------------

# %%
# load the CSV - lotr_testset.csv
import pandas as pd
import nest_asyncio

nest_asyncio.apply()
test_df = pd.read_csv('data/dost_testset.csv')

# %%
test_df
# Out:
#                                             question  \
# 0  What are the three main DOST-SEI undergraduate...
# 1  What is the monthly living allowance for DOST-...
# 2  What happens if a first-year scholar gets 2 gr...
# 3  How long must scholars render service in the P...
# 4  What are the eligibility criteria for RA 7687 ...
# 5  What is the maximum tuition fee subsidy and wh...
# 6  What are the grade requirements for second-yea...
# 7  What is the difference between deferring schol...
# 8  What are the requirements for practical traini...
# 9  What are the conditions for shifting program o...
#
#                                             contexts  \
# 0  ['The S&T Scholarship Programs aim to: a. Prov...
# 1  ['Scholarship Privileges Regular Academic Year...
# 2  ['Academic Deficiency Scholarship Status First...
# 3  ['After Graduation The scholar, immediately up...
# 4  ['Eligibility Criteria for the Undergraduate S...
# 5  ['Tuition and Other School Fees Subsidy Tuitio...
# 6  ['Second Year ? The scholar must have a semest...
# 7  ['Deferring the DOST-SEI Undergraduate Scholar...
# 8  ['The scholar shall undergo 240-hour practical...
# 9  ['The scholar may be allowed to shift to anoth...
#
#                                         ground_truth evolution_type  \
# 0  The three main DOST-SEI undergraduate scholars...         simple
# 1  The monthly living allowance for DOST-SEI scho...         simple
# 2  If a first-year scholar gets 2 grades of 5.0/F...         simple
# 3  Scholars must render service in the Philippine...         simple
# 4  For RA 7687 scholarship, graduating Grade 12 s...      reasoning
# 5  The maximum tuition fee subsidy is PHP 40,000....      reasoning
# 6  Second-year scholars must have a semestral wei...  multi_context
# 7  Deferring the DOST-SEI Undergraduate Scholarsh...      reasoning
# 8  Scholars must undergo 240-hour practical train...  multi_context
# 9  Scholars may shift programs or transfer school...  multi_context
#
#                                             metadata  episode_done
# 0  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 1  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 2  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 3  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 4  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 5  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 6  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 7  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 8  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True
# 9  [{'source': '2025-DOST-SEI-ST-Scholars-Handboo...          True

# %%
test_questions = test_df["question"].values.tolist()
test_groundtruths = test_df["ground_truth"].values.tolist()

# %%
answers = []
contexts = []

for question in test_questions:
    response = retrieval_chain.invoke({"input": question})
    answers.append(response["answer"])  # retrieval_chain outputs "answer"
    contexts.append([doc.page_content for doc in response["context"]])

# %%
from datasets import Dataset

response_dataset = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %%
response_dataset[0]
# Out:
# {'question': 'What are the three main DOST-SEI undergraduate scholarship programs?',
#  'answer': 'The three main DOST-SEI undergraduate scholarship programs are:\n\na. Merit Scholarship Program (RA 2067)  \nb. RA 7687 Scholarship Program  \nc. RA 10612 (under the Junior Level Science Scholarships)',
#  'contexts': ['The following are programs covered by the DOST-SEI Undergraduate Scholarship:\n•\t\nBachelor in Mathematics Education\n•\t\nBachelor in Technology and \nLivelihood Education with \nspecialization in Information and \nCommunications\n•\t\nBachelor of Library and Information \nScience\n•\t\nBS Aeronautical Engineering\n•\t\nBS Aerospace Engineering\n•\t\nBS Agribusiness\n•\t\nBS Agribusiness Economics\n•\t\nBS Agribusiness Management and \nEntrepreneurship',
#   'The DOST-SEI Undergraduate Scholarship Programs......................................................3  \na.  Merit Scholarship Program (RA 2067)  \nb.  RA 7687 Scholarship Program  \nc.  RA 10612 (under the Junior Level Science Scholarships)',
#   'The following are programs covered by the DOST-SEI Undergraduate Scholarship:\n•\t\nBS Life Sciences\n•\t\nBS Management Information \nSystems (2)\n•\t\nBS Manufacturing Engineering\n•\t\nBS Manufacturing Engineering-\nManagement-Biomedical \nEngineering (3)\n•\t\nBS Manufacturing Engineering-\nManagement-Mechatronics and \nRobotics (3)\n•\t\nBS Marine Biology\n•\t\nBS Marine Science\n•\t\nBS Materials Engineering\n•\t\nBS Mathematics\n•\t\nBS Mathematics and Science \nTeaching',
#   'A.\t Merit Scholarship Program (RA 2067)  \nThe DOST-SEI Merit Scholarship Program, formerly known as the NSDB or  \nNSTA Scholarship, began in 1958. It is awarded to students with high aptitude in  \nscience and mathematics and who are willing to pursue priority courses in the  \nbasic sciences, engineering, other applied sciences, and science and mathematics  \nteaching at identified universities.  \nB.\t RA 7687 Scholarship Program  \nRepublic Act No. 7687, also known as the “Science and Technology  \nScholarship Act of 1994”, provides for scholarships to talented and deserving'],
#  'ground_truth': "The three main DOST-SEI undergraduate scholarship programs are: 1) Merit Scholarship Program (RA 2067) - formerly known as NSDB or NSTA Scholarship that began in 1958; 2) RA 7687 Scholarship Program - for talented students whose families' socio-economic status doesn't exceed set cut-off values; and 3) RA 10612 (Junior Level Science Scholarships) - aimed at fast-tracking graduates to teach science and mathematics in secondary schools."}

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %%
import nest_asyncio

nest_asyncio.apply()
results = evaluate(response_dataset, metrics)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Convert results to DataFrame
import pandas as pd

# Extract metrics from results
results_dict = results.to_pandas()

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Metric': ['Faithfulness', 'Answer Relevancy', 'Context Recall', 'Context Precision', 'Answer Correctness'],
    'Score': [
        results_dict['faithfulness'].mean(),
        results_dict['answer_relevancy'].mean(), 
        results_dict['context_recall'].mean(),
        results_dict['context_precision'].mean(),
        results_dict['answer_correctness'].mean()
    ]
})

# Round scores to 3 decimal places
summary_df['Score'] = summary_df['Score'].round(3)

# Display the summary
print("RAGAS Evaluation Summary:")
print("=" * 40)
print(summary_df.to_string(index=False))

# Also display the full results DataFrame
print("\n\nDetailed Results:")
print("=" * 40)
print(results_dict)
# Out:
# RAGAS Evaluation Summary:
# ========================================
#             Metric  Score
#       Faithfulness  0.754
#   Answer Relevancy  0.881
#     Context Recall  0.667
#  Context Precision  0.721
# Answer Correctness  0.656
#
#
# Detailed Results:
# ========================================
#                                           user_input  \
# 0  What are the three main DOST-SEI undergraduate...
# 1  What is the monthly living allowance for DOST-...
# 2  What happens if a first-year scholar gets 2 gr...
# 3  How long must scholars render service in the P...
# 4  What are the eligibility criteria for RA 7687 ...
# 5  What is the maximum tuition fee subsidy and wh...
# 6  What are the grade requirements for second-yea...
# 7  What is the difference between deferring schol...
# 8  What are the requirements for practical traini...
# 9  What are the conditions for shifting program o...
#
#                                   retrieved_contexts  \
# 0  [The following are programs covered by the DOS...
# 1  [A monthly stipend will be provided for the du...
# 2  [2 Grades of 5.0/F at the end of the First Sem...
# 3  [Render service in the Philippines for a perio...
# 4  [I.\t\nFirst Year –  The scholar must have an ...
# 5  [Tuition and other school fees based on the St...
# 6  [The scholar must have passing grades in all a...
# 7  [F.\t Leave of Absence\nScholars may be allowe...
# 8  [E.\t Practical  Training  \nDuring the on-the...
# 9  [transfer schools in meritorious cases only, s...
#
#                                             response  \
# 0  The three main DOST-SEI undergraduate scholars...
# 1  The monthly living allowance for DOST-SEI scho...
# 2  If a first-year scholar gets 2 grades of 5.0/F...
# 3  Scholars must render service in the Philippine...
# 4  The eligibility criteria for the RA 7687 schol...
# 5  The maximum tuition fee subsidy is PHP 40,000....
# 6  For second-year scholars, the grade requiremen...
# 7  I need more specific information from the hand...
# 8  The requirements for practical training includ...
# 9  The conditions for shifting program or transfe...
#
#                                            reference  faithfulness  \
# 0  The three main DOST-SEI undergraduate scholars...      0.000000
# 1  The monthly living allowance for DOST-SEI scho...      0.666667
# 2  If a first-year scholar gets 2 grades of 5.0/F...      1.000000
# 3  Scholars must render service in the Philippine...      1.000000
# 4  For RA 7687 scholarship, graduating Grade 12 s...      1.000000
# 5  The maximum tuition fee subsidy is PHP 40,000....      1.000000
# 6  Second-year scholars must have a semestral wei...      0.875000
# 7  Deferring the DOST-SEI Undergraduate Scholarsh...      0.000000
# 8  Scholars must undergo 240-hour practical train...      1.000000
# 9  Scholars may shift programs or transfer school...      1.000000
#
#    answer_relevancy  context_recall  context_precision  answer_correctness
# 0          1.000000        0.333333           0.500000            0.544152
# 1          1.000000        1.000000           0.583333            0.999734
# 2          0.992432        1.000000           0.632107            0.617273
# 3          0.927341        1.000000           1.000000            0.998984
# 4          0.998497        0.000000           0.500000            0.221609
# 5          0.971976        1.000000           0.833333            0.914802
# 6          0.961038        0.333333           0.450000            0.579779
# 7          0.000000        0.500000           0.873413            0.182290
# 8          0.977860        0.500000           0.833333            0.734300
# 9          0.984657        1.000000           1.000000            0.771766

# %%
os.environ["TAVILY_API_KEY"] = getpass("Please provide your Tavily Key: ")

# %%
from tavily import TavilyClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 from tavily import TavilyClient
#
# ModuleNotFoundError: No module named 'tavily'
